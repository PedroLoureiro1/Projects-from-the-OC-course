# %% [markdown]
# ## 2.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### e)

# %% [markdown]
# Num Cycles = 23
# Num Instructions = 10
# CPI = Cycles/ Instructions = 2.3

# %% [markdown]
# ### f)

# %% [markdown]
# Clock cycles : 377
# Instructions : 166
# Average CPI : 2.271
#
# Stalls: - Data : 192
#         - Structural : 0
#         - Branch Taken : 15

# %% [markdown]
# ### g)
#
# A política de previsão de branches parece ser uma abordagem estática (Predict Branch Not Taken). Isso significa que, para cada instrução de branch, o simulador assume que o desvio não será tomado, gerando um stall sempre que essa suposição estiver errada(ou seja, o desvio é tomado).

# %% [markdown]
# ## 2.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### c)

# %% [markdown]
# Clock cycles : 297
# Instructions : 166
# Average CPI : 1.789
#
# Stalls: - Data : 112
#         - Structural : 16
#         - Branch Taken : 15

# %% [markdown]
# ### d)

# %% [markdown]
# Speedup = (CPI_sem_forwarding * IC * CC) / (CPI_com_forwarding * IC * CC)
#         = (2.271 * 166) / (1.789 * 166)
#         = 1.27

# %% [markdown]
# ## 2.3

# %% [markdown]
# ### b)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### c)

# %% [markdown]
# Clock cycles : 233
# Instructions : 166
# Average CPI : 1.404
#
# Stalls: - Data : 32
#         - Structural : 16
#         - Branch Taken : 15

# %% [markdown]
# ### d)

# %% [markdown]
# Speedup = (CPI_sem_forwarding * IC * CC) / (CPI_com_forwarding_reorder * IC * CC)
#         = (2.271 * 166) / (1.404* 166)
#         = 1.618

# %% [markdown]
# ### 2.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### c)

# %% [markdown]
# Clock cycles : 153
# Instructions : 126
# Average CPI : 1.214
#
# Stalls: - Data : 0
#         - Structural : 16
#         - Branch Taken : 7

# %% [markdown]
# ### d)

# %% [markdown]
# Speedup = (CPI_sem_forwarding * IC * CC) / (CPI_com_unrolling * IC * CC)
#         = (2.271 * 166) / (1.214* 126)
#         = 2,465

# %% [markdown]
# ### 2.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### d)

# %% [markdown]
# Clock cycles : 218
# Instructions : 166
# Average CPI : 1.313
#
# Stalls: - Data : 32
#         - Structural : 16
#         - Branch Taken : 0

# %% [markdown]
# ### e)

# %% [markdown]
# Speedup = (CPI_sem_forwarding * IC * CC) / (CPI_com_delayslot * IC * CC)
#         = (2.271 * 166) / (1.313 * 166)
#         = 1,730
